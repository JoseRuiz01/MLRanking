# %%
import pandas as pd
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
import os

# %% [markdown]
# # Query Mapping Dictionary
# The `query_mapping` dictionary links medical queries to their respective components and systems:
#
# - **"glucose in blood"** → Component: `glucose`, System: `blood`
# - **"bilirubin in plasma"** → Component: `bilirubin`, System: `plasma`
# - **"white blood cells count"** → Component: `leukocytes`, System: `blood`
# - **"calcium in serum"** → Component: `calcium`, System: `serum`

# %%
query_mapping = {
    "glucose in blood": {
        "component": "glucose",
        "system": "blood"
    },
    "bilirubin in plasma": {
        "component": "bilirubin",
        "system": "plasma"
    },
    "white blood cells count": {
        "component": "leukocytes",
        "system": "blood"
    },
    "calcium in serum": {
        "component": "calcium",
        "system": "serum"
    }, 
    "cells in urine": {
        "component": "cells",
        "system": "urine"
    }
}

file_path = "./LOINC_Dataset"

# %% [markdown]
# # Abbreviation Mapping, Stop Words, and Lemmatization
#
# This script performs **text preprocessing** by:
# - Expanding **abbreviations** into full terms using the dictionary `abbreviation_mapping`.
# - Removing **common stop words**.
# - Applying **lemmatization** to reduce words to their base forms.

# %%
abbreviation_mapping = {
    'c': 'component',
    'mcnc': 'mass concentration',
    'bld': 'blood',
    'scnc': 'substance concentration',
    'susc': 'susceptibility',
    'acnc': 'amount concentration',
    'plas': 'plasma',
    'ccnc': 'cell concentration',
    'ncnc': 'number concentration',
    'XXX': 'unknown',
    'bpu': 'blood product unit',
    'fld': 'fluid',
    'abo': 'abo blood group',
    'ser': 'serum',
    'mscnc': 'mass substance concentration',
    'bbl': 'blood product unit',
    'rbc': 'red blood cells', 
    'blda': 'blood group a',
    'bldv': 'blood group v', 
    'tiss': 'tissue',
    'bldco': 'coord blood',
    'csf': 'cerebrospinal fluid'
}

nltk.download("stopwords")
nltk.download("wordnet")

stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/joseantonioruizheredia/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/joseantonioruizheredia/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Text Preprocessing in a DataFrame
#
# This script performs text cleaning and abbreviation replacement on text columns in a DataFrame (`df`). It helps standardize text data for further analysis by removing noise and ensuring consistency.
#
# ## Functions
#
# ### 1. clean_text
# Cleans a given text string by:
# 1. Converting it to **lowercase**.
# 2. Removing **punctuation** (replacing non-alphanumeric characters with spaces).
# 3. **Tokenizing** (splitting the text into words).
# 4. Removing **stop words** (common words that don't contribute much meaning).
# 5. Applying **lemmatization** (reducing words to their base form).
#
# If the input is not a string, it returns an empty string.
#
# ### 2. replace_abbreviations
# Replaces known abbreviations in a given text using the `abbreviation_mapping` dictionary.
# - Splits the text into words.
# - Replaces each word if it exists in the abbreviation dictionary.
# - Returns the modified text.

# %%
def clean_text(text):
    if isinstance(text, str):
        text = text.lower() 
        text = re.sub(r'[^\w\s]', ' ', text)  
        words = text.split()  
        words = [word for word in words if word not in stop_words]  
        words = [lemmatizer.lemmatize(word) for word in words] 
        return " ".join(words)
    return ""


def replace_abbreviations(text):
    if isinstance(text, str):
        words = text.split()
        words = [abbreviation_mapping.get(word, word) for word in words]  
        return " ".join(words)
    return text

# %% [markdown]
# # Column Weights and Embedding Model Initialization
#
# This script defines **column weights** for a scoring system and initializes an **embedding model** for text similarity calculations.
#
# ## Column Weights
#
# The `column_weights` dictionary assigns importance to different columns when calculating scores:
#
# - **Higher weights** (e.g., `name`, `component`) indicate greater importance in the scoring process.
# - `loinc_num` has a weight of **0** because it is likely an identifier and does not contribute to similarity calculations.
#
# ## Embedding Model Initialization
#
# The script attempts to load an embedding model for text similarity using **SentenceTransformer**.

# %%
column_weights = {
    'name': 1.5,
    'component': 6.0,
    'long_common_name': 1.0,
    'system': 3.0,
    'property': 1.0,
    'measurement_type': 1.0,
    'loinc_num': 0,
    'status': 0.5,
    'example_units': 1.0
}

global embedding_model
if 'embedding_model' not in globals():
    try:
        embedding_model = SentenceTransformer('pritamdeka/BioBERT-MNLI')
    except:
        try:
            embedding_model = SentenceTransformer('all-MiniLM-L6-v2')
        except:
            embedding_model = None

# %% [markdown]
# # Relevance Score Calculation
# This script calculates a **relevance score** for each row in a dataset by comparing a query to the dataset's text fields using both **traditional keyword matching** and **semantic similarity via embeddings**.
#
#
# ### 1. calculate_score
# This function calculates the relevance score for a given row by:
# 1. Splitting the query into words and storing them in a set.
# 2. Initializing an empty dictionary to track matched words.
# 3. Computing the **traditional** relevance score.
# 4. Computing the **embedding-based** relevance score.
# 5. Combining both scores and optionally printing debug information.
#
#
# ### 2. get_query_embedding
# Encodes the query into an **embedding vector** using a pre-trained embedding model.
# - If the embedding model is available, it encodes the query.
# - If an error occurs, it prints an error message and returns `None`.
#
# ### 3. calculate_traditional_score
# This function calculates a **keyword matching score** based on:
# - The presence of query words in the main columns `component` and `system`
# - A predefined weight assigned to each column.
#
# ### 4. calculate_embedding_score
# This function computes the **semantic similarity score** between the query embedding and the row's text fields:
# - Encodes the text field into an embedding.
# - Uses **cosine similarity** to measure similarity between the query and field.
# - Converts the similarity score (ranging from -1 to 1) into a normalized range.
# - Applies column weights to adjust the score.
# - Adds the result to the final score.

# %%
def calculate_score(query, query_df, row, debug=False):
    query_embedding = get_query_embedding(query)
    debug_info = {"query": query, "embedding_score": [], "traditional_score": []}
    
    traditional_score = calculate_traditional_score(query, row, debug_info)
    embedding_score = calculate_embedding_score(query_embedding, query_df, row, debug_info)
    score = traditional_score + embedding_score
    
    debug_info["final_score"] = score
    
    if debug:
        print(debug_info)
   
    return score


def get_query_embedding(query):
    if embedding_model:
        try:
            return embedding_model.encode(query.lower())
        except Exception as e:
            print(f"Embedding encoding error: {e}")
    return None

def calculate_traditional_score(query, row, debug_info):
    score = 0
    
    query_component = query_mapping[query]["component"].lower()
    query_system = query_mapping[query]["system"].lower()


    component = row.get("COMPONENT", "").lower() 
    system = row.get("SYSTEM", "").lower()  
    
    if query_component == component:
        score += column_weights.get("component", 1.0)  * column_weights.get("component", 1.0) 
    elif query_component in component:
        score += (column_weights.get("component", 1.0) * 0.5) * column_weights.get("component", 1.0)   
    
    if query_system == system:
        score += column_weights.get("system", 1.0)  * column_weights.get("system", 1.0)  
    elif query_system in system:
        score += (column_weights.get("system", 1.0) * 0.5) * column_weights.get("system", 1.0) 

    debug_info["traditional_score"].append({"score": score})
        
    return score

def calculate_embedding_score(query_embedding, query_df, row, debug_info):
    score = 0
    if embedding_model and query_embedding is not None:
        for col in query_df.select_dtypes(include=["object"]).columns:
            if col in row and pd.notna(row[col]):
                cell_text = str(row[col]).lower()
                weight = column_weights.get(col, 1.0)
                try:
                    cell_embedding = embedding_model.encode(cell_text)
                    similarity = cosine_similarity([query_embedding], [cell_embedding])[0][0]
                    embedding_score = ((similarity + 1) / 2) * 5 * weight
                    score += embedding_score
                except Exception as e:
                    print(f"Embedding similarity error: {e}")
        debug_info["embedding_score"].append({"score": score})
    return score

# %% [markdown]
# # Preprocessing of the files
# The `process_folder` function processes multiple CSV files within a specified folder by cleaning and transforming the data, calculating scores based on predefined queries, and saving the enhanced dataset into a new CSV file. Here's a more detailed summary of its steps:
#
# ### 1. Data Preprocessing
#    - For each query, it processes the CSV files individually.
#    - After successfully reading the file, it standardizes the column names by stripping spaces and converting them to uppercase. Additionally, it renames the `"LONG_COMMON_NAME"` column to `"NAME"` for consistency.
#    - A new column, `MEASUREMENT_TYPE`, is added by extracting information from the `NAME` column using regular expressions.
#    - The function applies text cleaning to object-type columns (except `"LOINC_NUM"`), including removing unwanted characters and replacing abbreviations for better consistency and readability.
#
# ### 2. Score Calculation
#    - For each row in the dataset, the function calls `calculate_score` to compute a score based on the query and the row’s attributes. These scores, along with other relevant row data (like LOINC code, component, system, etc.), are appended to a results list.
#
# ### 3. Normalization and Deduplication
#    - Once all the data is processed, the results are converted into a DataFrame.
#    - The scores are normalized to a 0-1 scale.
#    - Duplicate rows grouped by query are removed based on the LOINC code.
#
# ### 4. Results
#    - The processed DataFrame is saved to the output CSV file. If the file already exists, the results are appended rather than overwriting the existing data.

# %%
def process_folder(csv_folder):
    csv_files = [f for f in os.listdir(csv_folder) if f.endswith(".csv")]
    output_filename = "./Dataset_with_scores/dataset_scores_enhanced.csv" 

    all_results = [] 

    for query_name, _ in query_mapping.items():
        print(f"Processing query: {query_name}")

        for csv_file in csv_files:
            file_path = os.path.join(csv_folder, csv_file)
            print(f"Reading file: {file_path}")

            try:
                dataset = pd.read_csv(file_path)
            except Exception as e:
                print(f"Skipping {csv_file} due to read error: {e}")
                continue  
            
            dataset.columns = dataset.columns.str.strip().str.upper()
            dataset.rename(columns={"LONG_COMMON_NAME": "NAME"}, inplace=True)
            dataset["MEASUREMENT_TYPE"] = dataset["NAME"].apply(
                lambda x: re.findall(r"\[(.*?)\]", x)[0] if isinstance(x, str) and "[" in x else ""
            )
            
            for col in dataset.select_dtypes(include=["object"]).columns:
                if col != "LOINC_NUM":  
                    dataset[col] = dataset[col].apply(clean_text)
                    dataset[col] = dataset[col].apply(replace_abbreviations)
            
            for _, row in dataset.iterrows():
                score = calculate_score(query_name, dataset, row, debug=(row.name < 3))
                all_results.append([
                    query_name, row.iloc[0], row.iloc[14], row.iloc[1], 
                    row.iloc[4], row.iloc[2], row.iloc[19], score
                ])

    if all_results:
        results_df = pd.DataFrame(all_results, columns=[
            "Query", "LOINC Code", "Name", "Component", "System", 
            "Property", "Measurement", "Score"
        ])

        min_score, max_score = results_df["Score"].min(), results_df["Score"].max()
        results_df["Normalized_Score"] = results_df["Score"].apply(
            lambda s: (s - min_score) / (max_score - min_score) if max_score != min_score else 1.0
        )
        
        results_df.drop(columns=["Score"], inplace=True)
        
        results_df = results_df.groupby("Query", group_keys=False).apply(
            lambda group: group.drop_duplicates(subset="LOINC Code", keep="first")
        )

        results_df.to_csv(output_filename, mode='a', index=False, header=not os.path.exists(output_filename))
        print(f"Results saved to {output_filename}")

process_folder(file_path)
# Out:
# Processing query: glucose in blood
# Reading file: ./LOINC_Dataset/bilirubin_in_plasma.csv
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(44.857346)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(44.857346)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(43.959023)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.959023)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(44.26867)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(44.26867)}
# Reading file: ./LOINC_Dataset/cells_in_urine.csv
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(42.057995)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.057995)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(41.484337)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(41.484337)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(41.12508)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(41.12508)}
# Reading file: ./LOINC_Dataset/glucose_in_blood.csv
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(47.45872)}], 'traditional_score': [{'score': 27.0}], 'final_score': np.float32(74.458725)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(48.840645)}], 'traditional_score': [{'score': 45.0}], 'final_score': np.float32(93.840645)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(47.926895)}], 'traditional_score': [{'score': 45.0}], 'final_score': np.float32(92.926895)}
# Reading file: ./LOINC_Dataset/bilirubin.csv
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(44.857346)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(44.857346)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(43.959023)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.959023)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(45.282856)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(49.782856)}
# Reading file: ./LOINC_Dataset/calcium.csv
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(44.00598)}], 'traditional_score': [{'score': 9.0}], 'final_score': np.float32(53.00598)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(42.872467)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.872467)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(42.801292)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.801292)}
# Reading file: ./LOINC_Dataset/serum_or_plasma.csv
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(42.821728)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.821728)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(43.414955)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(47.914955)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(44.47967)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(48.97967)}
# Reading file: ./LOINC_Dataset/urine.csv
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(44.990936)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(44.990936)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(44.8987)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(44.8987)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(45.1998)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(45.1998)}
# Reading file: ./LOINC_Dataset/blood.csv
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(44.117245)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(48.617245)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(43.99939)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(48.49939)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(43.959362)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(48.459362)}
# Reading file: ./LOINC_Dataset/white_blood_cells_count.csv
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(43.645943)}], 'traditional_score': [{'score': 9.0}], 'final_score': np.float32(52.645943)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(44.02397)}], 'traditional_score': [{'score': 9.0}], 'final_score': np.float32(53.02397)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(43.844345)}], 'traditional_score': [{'score': 9.0}], 'final_score': np.float32(52.844345)}
# Reading file: ./LOINC_Dataset/calcium_in_serum.csv
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(43.639725)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.639725)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(45.146683)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(45.146683)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(44.25197)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(44.25197)}
# Reading file: ./LOINC_Dataset/leukocytes.csv
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(44.53705)}], 'traditional_score': [{'score': 9.0}], 'final_score': np.float32(53.53705)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(42.17397)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.17397)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(42.966576)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.966576)}
# Reading file: ./LOINC_Dataset/cells.csv
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(42.56193)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(47.06193)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(42.996452)}], 'traditional_score': [{'score': 9.0}], 'final_score': np.float32(51.996452)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(42.93144)}], 'traditional_score': [{'score': 9.0}], 'final_score': np.float32(51.93144)}
# Reading file: ./LOINC_Dataset/glucose.csv
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(45.8398)}], 'traditional_score': [{'score': 18.0}], 'final_score': np.float32(63.8398)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(45.957035)}], 'traditional_score': [{'score': 18.0}], 'final_score': np.float32(63.957035)}
# {'query': 'glucose in blood', 'embedding_score': [{'score': np.float32(46.459873)}], 'traditional_score': [{'score': 18.0}], 'final_score': np.float32(64.45987)}
# Processing query: bilirubin in plasma
# Reading file: ./LOINC_Dataset/bilirubin_in_plasma.csv
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(48.367805)}], 'traditional_score': [{'score': 22.5}], 'final_score': np.float32(70.867805)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(47.504692)}], 'traditional_score': [{'score': 22.5}], 'final_score': np.float32(70.00469)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(47.00565)}], 'traditional_score': [{'score': 22.5}], 'final_score': np.float32(69.505646)}
# Reading file: ./LOINC_Dataset/cells_in_urine.csv
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(40.572147)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(40.572147)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(41.466713)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(41.466713)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(41.159126)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(41.159126)}
# Reading file: ./LOINC_Dataset/glucose_in_blood.csv
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(43.092686)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.092686)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(43.650566)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.650566)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(43.66833)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.66833)}
# Reading file: ./LOINC_Dataset/bilirubin.csv
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(48.367805)}], 'traditional_score': [{'score': 22.5}], 'final_score': np.float32(70.867805)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(47.504692)}], 'traditional_score': [{'score': 22.5}], 'final_score': np.float32(70.00469)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(47.28779)}], 'traditional_score': [{'score': 18.0}], 'final_score': np.float32(65.28779)}
# Reading file: ./LOINC_Dataset/calcium.csv
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(43.03446)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.03446)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(42.33031)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.33031)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(42.100906)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.100906)}
# Reading file: ./LOINC_Dataset/serum_or_plasma.csv
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(44.22367)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(48.72367)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(43.475395)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(47.975395)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(45.19337)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(49.69337)}
# Reading file: ./LOINC_Dataset/urine.csv
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(43.02678)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.02678)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(43.311707)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.311707)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(43.389713)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.389713)}
# Reading file: ./LOINC_Dataset/blood.csv
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(44.767433)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(44.767433)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(43.50928)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.50928)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(43.078262)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.078262)}
# Reading file: ./LOINC_Dataset/white_blood_cells_count.csv
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(43.40239)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.40239)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(43.330776)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.330776)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(43.19334)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.19334)}
# Reading file: ./LOINC_Dataset/calcium_in_serum.csv
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(44.061455)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(48.561455)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(44.77008)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(49.27008)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(43.302406)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(47.802406)}
# Reading file: ./LOINC_Dataset/leukocytes.csv
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(43.489494)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.489494)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(42.56272)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.56272)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(41.68633)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(41.68633)}
# Reading file: ./LOINC_Dataset/cells.csv
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(41.13755)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(41.13755)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(41.812973)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(41.812973)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(41.729042)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(41.729042)}
# Reading file: ./LOINC_Dataset/glucose.csv
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(42.00848)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.00848)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(43.25507)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(47.75507)}
# {'query': 'bilirubin in plasma', 'embedding_score': [{'score': np.float32(42.496136)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.496136)}
# Processing query: white blood cells count
# Reading file: ./LOINC_Dataset/bilirubin_in_plasma.csv
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(43.372105)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.372105)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(42.932438)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.932438)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(42.63177)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.63177)}
# Reading file: ./LOINC_Dataset/cells_in_urine.csv
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(41.286213)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(41.286213)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(40.39643)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(40.39643)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(40.27325)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(40.27325)}
# Reading file: ./LOINC_Dataset/glucose_in_blood.csv
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(43.217155)}], 'traditional_score': [{'score': 9.0}], 'final_score': np.float32(52.217155)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(44.10468)}], 'traditional_score': [{'score': 9.0}], 'final_score': np.float32(53.10468)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(43.693447)}], 'traditional_score': [{'score': 9.0}], 'final_score': np.float32(52.693447)}
# Reading file: ./LOINC_Dataset/bilirubin.csv
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(43.372105)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.372105)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(42.932438)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.932438)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(43.81616)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(48.31616)}
# Reading file: ./LOINC_Dataset/calcium.csv
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(42.83174)}], 'traditional_score': [{'score': 9.0}], 'final_score': np.float32(51.83174)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(41.55708)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(41.55708)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(41.535988)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(41.535988)}
# Reading file: ./LOINC_Dataset/serum_or_plasma.csv
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(41.85823)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(41.85823)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(42.83677)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(47.33677)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(42.63201)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(47.13201)}
# Reading file: ./LOINC_Dataset/urine.csv
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(42.993557)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.993557)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(42.697575)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.697575)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(42.620667)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.620667)}
# Reading file: ./LOINC_Dataset/blood.csv
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(44.742645)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(49.242645)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(43.679863)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(48.179863)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(44.631454)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(49.131454)}
# Reading file: ./LOINC_Dataset/white_blood_cells_count.csv
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(45.72285)}], 'traditional_score': [{'score': 9.0}], 'final_score': np.float32(54.72285)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(46.429672)}], 'traditional_score': [{'score': 9.0}], 'final_score': np.float32(55.429672)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(46.231556)}], 'traditional_score': [{'score': 9.0}], 'final_score': np.float32(55.231556)}
# Reading file: ./LOINC_Dataset/calcium_in_serum.csv
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(42.609707)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.609707)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(42.884796)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.884796)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(41.34362)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(41.34362)}
# Reading file: ./LOINC_Dataset/leukocytes.csv
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(44.892933)}], 'traditional_score': [{'score': 9.0}], 'final_score': np.float32(53.892933)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(43.002235)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.002235)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(43.670647)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.670647)}
# Reading file: ./LOINC_Dataset/cells.csv
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(42.041187)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(46.541187)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(42.516514)}], 'traditional_score': [{'score': 9.0}], 'final_score': np.float32(51.516514)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(42.56121)}], 'traditional_score': [{'score': 9.0}], 'final_score': np.float32(51.56121)}
# Reading file: ./LOINC_Dataset/glucose.csv
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(41.480606)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(41.480606)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(41.91603)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(41.91603)}
# {'query': 'white blood cells count', 'embedding_score': [{'score': np.float32(42.47478)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.47478)}
# Processing query: calcium in serum
# Reading file: ./LOINC_Dataset/bilirubin_in_plasma.csv
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(45.76221)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(50.26221)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(45.965458)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(50.465458)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(44.844936)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(49.344936)}
# Reading file: ./LOINC_Dataset/cells_in_urine.csv
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(42.158043)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.158043)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(43.259575)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.259575)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(42.849968)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.849968)}
# Reading file: ./LOINC_Dataset/glucose_in_blood.csv
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(45.086628)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(45.086628)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(45.12996)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(45.12996)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(45.962788)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(45.962788)}
# Reading file: ./LOINC_Dataset/bilirubin.csv
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(45.76221)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(50.26221)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(45.965458)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(50.465458)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(44.839676)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(44.839676)}
# Reading file: ./LOINC_Dataset/calcium.csv
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(48.521214)}], 'traditional_score': [{'score': 18.0}], 'final_score': np.float32(66.52121)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(47.22633)}], 'traditional_score': [{'score': 18.0}], 'final_score': np.float32(65.22633)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(47.33527)}], 'traditional_score': [{'score': 18.0}], 'final_score': np.float32(65.335266)}
# Reading file: ./LOINC_Dataset/serum_or_plasma.csv
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(47.021698)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(51.521698)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(43.710495)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(48.210495)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(46.141693)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(50.641693)}
# Reading file: ./LOINC_Dataset/urine.csv
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(44.67515)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(44.67515)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(44.619476)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(44.619476)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(45.423977)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(45.423977)}
# Reading file: ./LOINC_Dataset/blood.csv
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(44.652084)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(44.652084)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(43.318375)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.318375)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(42.96506)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.96506)}
# Reading file: ./LOINC_Dataset/white_blood_cells_count.csv
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(43.881283)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.881283)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(43.759186)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.759186)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(43.378937)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.378937)}
# Reading file: ./LOINC_Dataset/calcium_in_serum.csv
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(48.670383)}], 'traditional_score': [{'score': 22.5}], 'final_score': np.float32(71.17038)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(49.457405)}], 'traditional_score': [{'score': 40.5}], 'final_score': np.float32(89.957405)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(48.38804)}], 'traditional_score': [{'score': 40.5}], 'final_score': np.float32(88.88804)}
# Reading file: ./LOINC_Dataset/leukocytes.csv
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(43.95607)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.95607)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(42.54201)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.54201)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(43.104927)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.104927)}
# Reading file: ./LOINC_Dataset/cells.csv
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(43.274773)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.274773)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(43.41253)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.41253)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(43.414738)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.414738)}
# Reading file: ./LOINC_Dataset/glucose.csv
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(43.0369)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.0369)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(44.18587)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(44.18587)}
# {'query': 'calcium in serum', 'embedding_score': [{'score': np.float32(44.337303)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(44.337303)}
# Processing query: cells in urine
# Reading file: ./LOINC_Dataset/bilirubin_in_plasma.csv
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(42.785473)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.785473)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(43.21834)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.21834)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(42.7779)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.7779)}
# Reading file: ./LOINC_Dataset/cells_in_urine.csv
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(46.34504)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(50.84504)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(46.57202)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(51.07202)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(46.115807)}], 'traditional_score': [{'score': 4.5}], 'final_score': np.float32(50.615807)}
# Reading file: ./LOINC_Dataset/glucose_in_blood.csv
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(43.346256)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.346256)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(44.069756)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(44.069756)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(44.555832)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(44.555832)}
# Reading file: ./LOINC_Dataset/bilirubin.csv
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(42.785473)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.785473)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(43.21834)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.21834)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(43.020275)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.020275)}
# Reading file: ./LOINC_Dataset/calcium.csv
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(43.48727)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.48727)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(45.359726)}], 'traditional_score': [{'score': 9.0}], 'final_score': np.float32(54.359726)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(45.212692)}], 'traditional_score': [{'score': 9.0}], 'final_score': np.float32(54.212692)}
# Reading file: ./LOINC_Dataset/serum_or_plasma.csv
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(43.81124)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.81124)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(42.526123)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.526123)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(44.57342)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(44.57342)}
# Reading file: ./LOINC_Dataset/urine.csv
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(48.164154)}], 'traditional_score': [{'score': 9.0}], 'final_score': np.float32(57.164154)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(48.188763)}], 'traditional_score': [{'score': 9.0}], 'final_score': np.float32(57.188763)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(48.084858)}], 'traditional_score': [{'score': 9.0}], 'final_score': np.float32(57.084858)}
# Reading file: ./LOINC_Dataset/blood.csv
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(43.95694)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.95694)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(43.12768)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.12768)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(43.480637)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.480637)}
# Reading file: ./LOINC_Dataset/white_blood_cells_count.csv
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(44.41735)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(44.41735)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(44.8862)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(44.8862)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(44.566933)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(44.566933)}
# Reading file: ./LOINC_Dataset/calcium_in_serum.csv
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(43.27919)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.27919)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(43.456295)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.456295)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(42.921455)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(42.921455)}
# Reading file: ./LOINC_Dataset/leukocytes.csv
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(44.160923)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(44.160923)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(43.33179)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.33179)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(44.63791)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(44.63791)}
# Reading file: ./LOINC_Dataset/cells.csv
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(43.284534)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(43.284534)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(44.34453)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(44.34453)}
# {'query': 'cells in urine', 'embedding_score': [{'score': np.float32(44.297745)}], 'traditional_score': [{'score': 0}], 'final_score': np.float32(44.297745)}
